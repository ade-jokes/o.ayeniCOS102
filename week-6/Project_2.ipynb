# %%
import tkinter as tk
from tkinter import messagebox

def computer_science():
    grades = ['A', 'B', 'C']
    jamb_score = int(jamb_entry.get())
    maths = maths_entry.get()
    eng = eng_entry.get()
    phy = phy_entry.get()
    chem = chem_entry.get()
    furth = furth_entry.get()

    # Create a Tkinter window
    kid = tk.Toplevel(root)
    kid.title("Computer Science")

    tk.Label(kid, text="Jamb_score:").pack()
    jamb_entry = tk.Entry(kid)
    jamb_entry.pack()

    tk.Label(kid, text="Score for Maths:").pack()
    maths_entry = tk.Entry(kid)
    maths_entry.pack()

    tk.Label(kid, text="Score for English:").pack()
    eng_entry = tk.Entry(kid)
    eng_entry.pack()

    tk.Label(kid, text="Score in Physics:").pack()
    phy_entry = tk.Entry(kid)
    phy_entry.pack()

    tk.Label(kid, text="Score in Chemistry:").pack()
    chem_entry = tk.Entry(kid)
    chem_entry.pack()

    tk.Label(kid, text="Score in Further Mathematics:").pack()
    furth_entry = tk.Entry(kid)
    furth_entry.pack()

    if jamb_score < 280 and maths not in grades and eng not in grades and phy not in grades and chem not in grades and furth not in grades:
        messagebox.showinfo("Result", "You are not admitted")
    else:
        messagebox.showinfo("Result", "You are admitted")

    return

def mass_communication():
    grades = ['A', 'B', 'C']
    jamb_score1 = int(jamb_entry1.get())
    math = math_entry.get()
    english = english_entry.get()
    literature = literature_entry.get()
    crs = crs_entry.get()
    government = government_entry.get()

    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Mass Communication")

    tk.Label(window, text="Jamb_score:").pack()
    jamb_entry1 = tk.Entry(window)
    jamb_entry1.pack()

    tk.Label(window, text="Score for Maths:").pack()
    math_entry = tk.Entry(window)
    math_entry.pack()

    tk.Label(window, text="Score for English:").pack()
    english_entry = tk.Entry(window)
    english_entry.pack()

    tk.Label(window, text="Score in Literature-In-English:").pack()
    literature_entry = tk.Entry(window)
    literature_entry.pack()

    tk.Label(window, text="Score in C.R.S:").pack()
    crs_entry = tk.Entry(window)
    crs_entry.pack()

    tk.Label(window, text="Score in Government:").pack()
    government_entry = tk.Entry(window)
    government_entry.pack()

    if jamb_score1 < 250 and math not in grades and english not in grades and literature not in grades and government not in grades and crs not in grades:
        messagebox.showinfo("Result", "You are not admitted")
    else:
        messagebox.showinfo("Result", "You are admitted")

root = tk.Tk()
root.title("Admission System")
tk.Label(root, text="Welcome to our portal where you can check if you are admitted or not.")
tk.Label(root, text="Do you want to go to computer/mass comm")

comput_button = tk.Button(root, text="Computer Science", command=computer_science)
comput_button.pack()
mass_button = tk.Button(root, text="Mass Communication", command=mass_communication)
mass_button.pack()

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Omotayo\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Omotayo\AppData\Local\Temp\ipykernel_47620\1400105517.py", line 50, in mass_communication
#     jamb_score1 = int(jamb_entry1.get())
#                       ^^^^^^^^^^^
# UnboundLocalError: cannot access local variable 'jamb_entry1' where it is not associated with a value
